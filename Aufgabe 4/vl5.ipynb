# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
torch.cuda.is_available()
# Out:
# 2.0.0+cpu
# None
# False

# %%
import numpy as np
values = np.loadtxt('vl5_data.csv')
import matplotlib.pyplot as plt
t_u = torch.tensor(values[:,1])
t_c = torch.tensor(values[:,0])
plt.plot(t_u, t_c, 'x')

# %%
def model(t_u, w, b):
    return w * t_u + b

def loss_fn(t_p, t_c):
    sq_diff = (t_p - t_c)**2
    return sq_diff.mean()

# %%
w = torch.ones(1)
b = torch.zeros(1)
t_p = model(t_u, w, b)
plt.plot(t_u, t_c, 'x')
plt.plot(t_u, t_p, 'x')
plt.show()
print(loss_fn(t_p, t_c))
# Out:
# tensor(1763.8845, dtype=torch.float64)

# %%
delta = 0.1

loss_rate_of_change_w = (loss_fn(model(t_u, w+delta, b), t_c) - loss_fn(model(t_u, w-delta, b), t_c))/(2.0 * delta)
loss_rate_of_change_b = (loss_fn(model(t_u, w, b+delta), t_c) - loss_fn(model(t_u, w, b-delta), t_c))/(2.0 * delta)

# %%
w = torch.ones(1)
b = torch.zeros(1)
learning_rate = 1e-5
for i in range(20):
    t_p = model(t_u, w, b)
    print(f'loss_fn = {loss_fn(t_p, t_c)}')
    w = w - learning_rate*loss_rate_of_change_w
    b = b - learning_rate*loss_rate_of_change_b
    
t_p = model(t_u, w, b)
plt.plot(t_u, t_c, 'x')
plt.plot(t_u, t_p, 'x')
plt.show()
print(loss_fn(t_p, t_c))
# Out:
# loss_fn = 1763.8845454545458
# loss_fn = 1565.7613932795966
# loss_fn = 1379.647953172533
# loss_fn = 1205.544225133356
# loss_fn = 1043.4502091620643
# loss_fn = 893.3659052448772
# loss_fn = 755.2913133977559
# loss_fn = 629.2264336207004
# loss_fn = 515.171265913711
# loss_fn = 413.1258102767874
# loss_fn = 323.09006670992983
# loss_fn = 245.06403521313806
# loss_fn = 179.04771578641237
# loss_fn = 125.0411084297525
# loss_fn = 83.04421314315856
# loss_fn = 53.057029926630555
# loss_fn = 35.07955878016849
# loss_fn = 29.11179969071484
# loss_fn = 35.15374475062026
# loss_fn = 53.20539395988475
# tensor(83.2667, dtype=torch.float64)

# %%
def dloss_fn(t_p, t_c):
    return 2*(t_p-t_c) / t_p.size(0)

def dmodel_dw(t_u, w, b):
    return t_u

def dmodel_db(t_u, w, b):
    return 1.0

def grad_fn(t_u, t_c, t_p, w, b):
    dloss_dtp = dloss_fn(t_p, t_c)
    dloss_dw = dloss_dtp * dmodel_dw(t_u, w, b)
    dloss_db = dloss_dtp * dmodel_db(t_u, w, b)
    return torch.stack([dloss_dw.sum(), dloss_db.sum()])

# %%
w = torch.ones(1)
b = torch.zeros(1)
learning_rate = 1e-3
for i in range(20):
    t_p = model(t_u, w, b)
    print(f'loss_fn = {loss_fn(t_p, t_c)}')
    grad = grad_fn(t_u, t_c, t_p, w, b)
    w = w - learning_rate*grad[0]
    b = b - learning_rate*grad[1]
    
t_p = model(t_u, w, b)
plt.plot(t_u, t_c, 'x')
plt.plot(t_u, t_p, 'x')
plt.show()
print(loss_fn(t_p, t_c))
# Out:
# loss_fn = 1763.8845454545458
# loss_fn = 41399.58620778713
# loss_fn = 986624.299525972
# loss_fn = 23528156.490046952
# loss_fn = 561094193.3334918
# loss_fn = 13380863399.17997
# loss_fn = 319104196719.3658
# loss_fn = 7609933912583.775
# loss_fn = 181480220610500.25
# loss_fn = 4327904646205531.0
# loss_fn = 1.0321100667296523e+17
# loss_fn = 2.461355781296724e+18
# loss_fn = 5.869792429665394e+19
# loss_fn = 1.3998163199524652e+21
# loss_fn = 3.338254548727587e+22
# loss_fn = 7.961003194697937e+23
# loss_fn = 1.898524226191001e+25
# loss_fn = 4.5275630117831364e+26
# loss_fn = 1.0797241851774887e+28
# loss_fn = 2.574904923843859e+29
# tensor(6.1406e+30, dtype=torch.float64)

# %%
t_un = t_u * 0.1

# %%
w = torch.ones(1)
b = torch.zeros(1)
learning_rate = 1e-2
for i in range(20):
    t_p = model(t_un, w, b)
    print(f'loss_fn = {loss_fn(t_p, t_c)}')
    grad = grad_fn(t_un, t_c, t_p, w, b)
    w = w - learning_rate*grad[0]
    b = b - learning_rate*grad[1]
    
t_p = model(t_un, w, b)
plt.plot(t_u, t_c, 'x')
plt.plot(t_u, t_p, 'x')
plt.show()
print(loss_fn(t_p, t_c))
# Out:
# loss_fn = 80.36434545454544
# loss_fn = 37.574911732266536
# loss_fn = 30.871081047363017
# loss_fn = 29.756195275714166
# loss_fn = 29.50714752719622
# loss_fn = 29.392453862949274
# loss_fn = 29.298826302053385
# loss_fn = 29.208718926609627
# loss_fn = 29.11941323410978
# loss_fn = 29.030487525771832
# loss_fn = 28.94187568154292
# loss_fn = 28.853566422912266
# loss_fn = 28.765557272031653
# loss_fn = 28.677846899762244
# loss_fn = 28.59043427437194
# loss_fn = 28.503318326381315
# loss_fn = 28.416498128131447
# loss_fn = 28.32997272522695
# loss_fn = 28.2437409583309
# loss_fn = 28.157801900132505
# tensor(28.0722, dtype=torch.float64)

# %%
def training_loop(n_epochs, learning_rate, params, t_u, t_c):
    for i in range(n_epochs):
        t_p = model(t_u, *params)
        print(f'loss_fn = {loss_fn(t_p, t_c)}')
        grad = grad_fn(t_u, t_c, t_p, *params)
        params = params - learning_rate * grad
    return params

# %%
w = torch.ones(1)
b = torch.zeros(1)
learning_rate = 1e-2

t_un = t_u * 0.1
params = training_loop(500, learning_rate, torch.tensor([w, b]), t_un, t_c)

t_p = model(t_un, *params)
plt.plot(t_u, t_c, 'x')
plt.plot(t_u, t_p, 'x')
plt.show()
print(loss_fn(t_p, t_c))
# Out:
# loss_fn = 80.36434545454544
# loss_fn = 37.57491443720965
# loss_fn = 30.87108149399124
# loss_fn = 29.756196009195058
# loss_fn = 29.507148000491892
# loss_fn = 29.39245416713703
# loss_fn = 29.298826583908706
# loss_fn = 29.208719127832026
# loss_fn = 29.11941350320999
# loss_fn = 29.030487848051678
# loss_fn = 28.941875959000978
# loss_fn = 28.85356671758456
# loss_fn = 28.765557539430105
# loss_fn = 28.67784716479513
# loss_fn = 28.59043454200422
# loss_fn = 28.50331865451376
# loss_fn = 28.416498494118965
# loss_fn = 28.32997305679455
# loss_fn = 28.243741342040803
# loss_fn = 28.15780235277251
# loss_fn = 28.072155095292
# loss_fn = 27.98679857927527
# loss_fn = 27.901731817760187
# loss_fn = 27.816953827135034
# loss_fn = 27.732463627127036
# loss_fn = 27.64826024079117
# loss_fn = 27.564342694498734
# loss_fn = 27.480710017926143
# loss_fn = 27.397361244043758
# loss_fn = 27.314295409104588
# loss_fn = 27.231511552633265
# loss_fn = 27.149008717414873
# loss_fn = 27.066785949483894
# loss_fn = 26.98484229811317
# loss_fn = 26.903176815802922
# loss_fn = 26.821788558269805
# loss_fn = 26.74067658443596
# loss_fn = 26.659839956418146
# loss_fn = 26.579277739516897
# loss_fn = 26.49898900220572
# loss_fn = 26.418972816120323
# loss_fn = 26.33922825604784
# loss_fn = 26.25975439991622
# loss_fn = 26.180550328783468
# loss_fn = 26.1016151268271
# loss_fn = 26.02294788133349
# loss_fn = 25.944547682687368
# loss_fn = 25.866413624361257
# loss_fn = 25.788544802905037
# loss_fn = 25.710940317935442
# loss_fn = 25.633599272125718
# loss_fn = 25.556520771195178
# loss_fn = 25.47970392389892
# loss_fn = 25.403147842017475
# loss_fn = 25.326851640346582
# loss_fn = 25.250814436686916
# loss_fn = 25.175035351833888
# loss_fn = 25.099513509567508
# loss_fn = 25.024248036642224
# loss_fn = 24.949238062776843
# loss_fn = 24.87448272064448
# loss_fn = 24.799981145862436
# loss_fn = 24.72573247698241
# loss_fn = 24.651735855480275
# loss_fn = 24.577990425746364
# loss_fn = 24.50449533507548
# loss_fn = 24.431249733657015
# loss_fn = 24.35825277456519
# loss_fn = 24.28550361374926
# loss_fn = 24.213001410023676
# loss_fn = 24.140745325058425
# loss_fn = 24.068734523369343
# loss_fn = 23.996968172308403
# loss_fn = 23.925445442054148
# loss_fn = 23.854165505602033
# loss_fn = 23.783127538754915
# loss_fn = 23.712330720113496
# loss_fn = 23.641774231066826
# loss_fn = 23.571457255782864
# loss_fn = 23.50137898119899
# loss_fn = 23.431538597012675
# loss_fn = 23.361935295672037
# loss_fn = 23.29256827236657
# loss_fn = 23.2234367250178
# loss_fn = 23.15453985427001
# loss_fn = 23.08587686348102
# loss_fn = 23.01744695871293
# loss_fn = 22.949249348723036
# loss_fn = 22.881283244954556
# loss_fn = 22.8135478615276
# loss_fn = 22.746042415230043
# loss_fn = 22.6787661255085
# loss_fn = 22.611718214459287
# loss_fn = 22.544897906819376
# loss_fn = 22.478304429957532
# loss_fn = 22.411937013865277
# loss_fn = 22.34579489114808
# loss_fn = 22.2798772970164
# loss_fn = 22.214183469276893
# loss_fn = 22.148712648323585
# loss_fn = 22.08346407712911
# loss_fn = 22.01843700123588
# loss_fn = 21.953630668747483
# loss_fn = 21.889044330319873
# loss_fn = 21.8246772391528
# loss_fn = 21.76052865098108
# loss_fn = 21.696597824066096
# loss_fn = 21.632884019187113
# loss_fn = 21.56938649963283
# loss_fn = 21.506104531192783
# loss_fn = 21.443037382148884
# loss_fn = 21.380184323266988
# loss_fn = 21.317544627788433
# loss_fn = 21.25511757142161
# loss_fn = 21.19290243233364
# loss_fn = 21.130898491142013
# loss_fn = 21.069105030906258
# loss_fn = 21.007521337119627
# loss_fn = 20.946146697700918
# loss_fn = 20.884980402986155
# loss_fn = 20.824021745720405
# loss_fn = 20.76327002104963
# loss_fn = 20.70272452651251
# loss_fn = 20.642384562032326
# loss_fn = 20.582249429908863
# loss_fn = 20.522318434810366
# loss_fn = 20.46259088376545
# loss_fn = 20.403066086155135
# loss_fn = 20.343743353704834
# loss_fn = 20.284622000476414
# loss_fn = 20.225701342860248
# loss_fn = 20.166980699567308
# loss_fn = 20.10845939162132
# loss_fn = 20.050136742350844
# loss_fn = 19.992012077381563
# loss_fn = 19.934084724628356
# loss_fn = 19.876354014287614
# loss_fn = 19.818819278829455
# loss_fn = 19.761479852990036
# loss_fn = 19.704335073763847
# loss_fn = 19.647384280396018
# loss_fn = 19.590626814374726
# loss_fn = 19.53406201942356
# loss_fn = 19.477689241493884
# loss_fn = 19.421507828757385
# loss_fn = 19.365517131598434
# loss_fn = 19.309716502606612
# loss_fn = 19.25410529656925
# loss_fn = 19.198682870463912
# loss_fn = 19.143448583451
# loss_fn = 19.088401796866346
# loss_fn = 19.033541874213807
# loss_fn = 18.978868181157903
# loss_fn = 18.924380085516525
# loss_fn = 18.870076957253563
# loss_fn = 18.81595816847167
# loss_fn = 18.762023093404967
# loss_fn = 18.708271108411836
# loss_fn = 18.65470159196769
# loss_fn = 18.601313924657816
# loss_fn = 18.548107489170153
# loss_fn = 18.495081670288208
# loss_fn = 18.44223585488394
# loss_fn = 18.38956943191063
# loss_fn = 18.337081792395864
# loss_fn = 18.284772329434457
# loss_fn = 18.23264043818145
# loss_fn = 18.180685515845106
# loss_fn = 18.128906961679963
# loss_fn = 18.077304176979876
# loss_fn = 18.025876565071055
# loss_fn = 17.974623531305248
# loss_fn = 17.923544483052797
# loss_fn = 17.8726388296958
# loss_fn = 17.82190598262128
# loss_fn = 17.771345355214446
# loss_fn = 17.72095636285178
# loss_fn = 17.6707384228944
# loss_fn = 17.62069095468124
# loss_fn = 17.57081337952238
# loss_fn = 17.521105120692365
# loss_fn = 17.471565603423475
# loss_fn = 17.422194254899136
# loss_fn = 17.372990504247287
# loss_fn = 17.323953782533767
# loss_fn = 17.27508352275574
# loss_fn = 17.226379159835133
# loss_fn = 17.177840130612108
# loss_fn = 17.129465873838566
# loss_fn = 17.08125583017164
# loss_fn = 17.033209442167195
# loss_fn = 16.98532615427348
# loss_fn = 16.937605412824574
# loss_fn = 16.8900466660341
# loss_fn = 16.842649363988784
# loss_fn = 16.7954129586421
# loss_fn = 16.74833690380795
# loss_fn = 16.701420655154323
# loss_fn = 16.65466367019705
# loss_fn = 16.608065408293463
# loss_fn = 16.561625330636215
# loss_fn = 16.515342900246992
# loss_fn = 16.469217581970337
# loss_fn = 16.42324884246744
# loss_fn = 16.377436150210016
# loss_fn = 16.33177897547407
# loss_fn = 16.286276790333883
# loss_fn = 16.24092906865583
# loss_fn = 16.195735286092315
# loss_fn = 16.15069492007572
# loss_fn = 16.10580744981236
# loss_fn = 16.061072356276433
# loss_fn = 16.016489122204078
# loss_fn = 15.972057232087314
# loss_fn = 15.927776172168167
# loss_fn = 15.88364543043267
# loss_fn = 15.839664496604938
# loss_fn = 15.795832862141305
# loss_fn = 15.752150020224436
# loss_fn = 15.708615465757445
# loss_fn = 15.665228695358058
# loss_fn = 15.621989207352824
# loss_fn = 15.578896501771283
# loss_fn = 15.535950080340188
# loss_fn = 15.493149446477759
# loss_fn = 15.450494105287914
# loss_fn = 15.407983563554586
# loss_fn = 15.365617329735983
# loss_fn = 15.323394913958937
# loss_fn = 15.281315828013202
# loss_fn = 15.239379585345835
# loss_fn = 15.197585701055566
# loss_fn = 15.155933691887201
# loss_fn = 15.114423076226005
# loss_fn = 15.073053374092147
# loss_fn = 15.03182410713519
# loss_fn = 14.990734798628477
# loss_fn = 14.9497849734637
# loss_fn = 14.908974158145353
# loss_fn = 14.868301880785276
# loss_fn = 14.827767671097211
# loss_fn = 14.787371060391353
# loss_fn = 14.747111581568912
# loss_fn = 14.706988769116741
# loss_fn = 14.66700215910194
# loss_fn = 14.627151289166498
# loss_fn = 14.587435698521926
# loss_fn = 14.547854927943966
# loss_fn = 14.508408519767256
# loss_fn = 14.469096017880025
# loss_fn = 14.429916967718862
# loss_fn = 14.390870916263406
# loss_fn = 14.351957412031162
# loss_fn = 14.313176005072249
# loss_fn = 14.274526246964188
# loss_fn = 14.236007690806751
# loss_fn = 14.197619891216759
# loss_fn = 14.15936240432296
# loss_fn = 14.121234787760882
# loss_fn = 14.083236600667714
# loss_fn = 14.045367403677217
# loss_fn = 14.007626758914643
# loss_fn = 13.970014229991678
# loss_fn = 13.932529382001372
# loss_fn = 13.895171781513143
# loss_fn = 13.857940996567743
# loss_fn = 13.820836596672263
# loss_fn = 13.783858152795165
# loss_fn = 13.747005237361329
# loss_fn = 13.710277424247089
# loss_fn = 13.673674288775295
# loss_fn = 13.63719540771047
# loss_fn = 13.600840359253823
# loss_fn = 13.564608723038445
# loss_fn = 13.5285000801244
# loss_fn = 13.49251401299392
# loss_fn = 13.456650105546542
# loss_fn = 13.42090794309433
# loss_fn = 13.385287112357053
# loss_fn = 13.349787201457428
# loss_fn = 13.314407799916331
# loss_fn = 13.279148498648066
# loss_fn = 13.244008889955659
# loss_fn = 13.208988567526085
# loss_fn = 13.174087126425643
# loss_fn = 13.139304163095197
# loss_fn = 13.104639275345583
# loss_fn = 13.070092062352892
# loss_fn = 13.03566212465389
# loss_fn = 13.001349064141374
# loss_fn = 12.967152484059557
# loss_fn = 12.933071988999508
# loss_fn = 12.899107184894568
# loss_fn = 12.865257679015764
# loss_fn = 12.831523079967344
# loss_fn = 12.797902997682161
# loss_fn = 12.764397043417226
# loss_fn = 12.731004829749178
# loss_fn = 12.697725970569842
# loss_fn = 12.664560081081701
# loss_fn = 12.63150677779353
# loss_fn = 12.59856567851589
# loss_fn = 12.565736402356746
# loss_fn = 12.533018569717056
# loss_fn = 12.500411802286374
# loss_fn = 12.467915723038487
# loss_fn = 12.435529956227041
# loss_fn = 12.403254127381215
# loss_fn = 12.371087863301367
# loss_fn = 12.339030792054752
# loss_fn = 12.307082542971186
# loss_fn = 12.275242746638792
# loss_fn = 12.24351103489969
# loss_fn = 12.21188704084578
# loss_fn = 12.180370398814484
# loss_fn = 12.148960744384505
# loss_fn = 12.11765771437163
# loss_fn = 12.086460946824529
# loss_fn = 12.055370081020556
# loss_fn = 12.024384757461597
# loss_fn = 11.993504617869899
# loss_fn = 11.962729305183938
# loss_fn = 11.932058463554277
# loss_fn = 11.901491738339466
# loss_fn = 11.87102877610193
# loss_fn = 11.840669224603891
# loss_fn = 11.81041273280328
# loss_fn = 11.780258950849708
# loss_fn = 11.750207530080383
# loss_fn = 11.720258123016107
# loss_fn = 11.690410383357243
# loss_fn = 11.660663965979722
# loss_fn = 11.631018526931047
# loss_fn = 11.601473723426313
# loss_fn = 11.572029213844228
# loss_fn = 11.542684657723212
# loss_fn = 11.513439715757409
# loss_fn = 11.484294049792792
# loss_fn = 11.455247322823237
# loss_fn = 11.426299198986639
# loss_fn = 11.397449343561028
# loss_fn = 11.36869742296068
# loss_fn = 11.340043104732297
# loss_fn = 11.31148605755111
# loss_fn = 11.283025951217097
# loss_fn = 11.254662456651143
# loss_fn = 11.226395245891235
# loss_fn = 11.198223992088682
# loss_fn = 11.170148369504306
# loss_fn = 11.142168053504717
# loss_fn = 11.11428272055852
# loss_fn = 11.086492048232607
# loss_fn = 11.058795715188404
# loss_fn = 11.03119340117817
# loss_fn = 11.003684787041287
# loss_fn = 10.976269554700572
# loss_fn = 10.948947387158599
# loss_fn = 10.921717968494036
# loss_fn = 10.89458098385799
# loss_fn = 10.867536119470362
# loss_fn = 10.840583062616222
# loss_fn = 10.813721501642204
# loss_fn = 10.786951125952879
# loss_fn = 10.760271626007189
# loss_fn = 10.73368269331484
# loss_fn = 10.707184020432774
# loss_fn = 10.680775300961578
# loss_fn = 10.65445622954195
# loss_fn = 10.628226501851179
# loss_fn = 10.602085814599612
# loss_fn = 10.57603386552717
# loss_fn = 10.550070353399825
# loss_fn = 10.524194978006129
# loss_fn = 10.498407440153748
# loss_fn = 10.472707441666005
# loss_fn = 10.447094685378403
# loss_fn = 10.42156887513523
# loss_fn = 10.396129715786117
# loss_fn = 10.370776913182612
# loss_fn = 10.34551017417479
# loss_fn = 10.32032920660788
# loss_fn = 10.295233719318858
# loss_fn = 10.270223422133087
# loss_fn = 10.245298025860983
# loss_fn = 10.220457242294657
# loss_fn = 10.195700784204554
# loss_fn = 10.1710283653362
# loss_fn = 10.146439700406823
# loss_fn = 10.121934505102091
# loss_fn = 10.097512496072815
# loss_fn = 10.073173390931675
# loss_fn = 10.048916908249952
# loss_fn = 10.024742767554283
# loss_fn = 10.000650689323406
# loss_fn = 9.976640394984924
# loss_fn = 9.952711606912109
# loss_fn = 9.928864048420664
# loss_fn = 9.905097443765532
# loss_fn = 9.881411518137725
# loss_fn = 9.857805997661114
# loss_fn = 9.83428060938931
# loss_fn = 9.810835081302432
# loss_fn = 9.787469142304056
# loss_fn = 9.764182522217999
# loss_fn = 9.740974951785244
# loss_fn = 9.717846162660807
# loss_fn = 9.69479588741064
# loss_fn = 9.671823859508534
# loss_fn = 9.64892981333304
# loss_fn = 9.626113484164405
# loss_fn = 9.60337460818149
# loss_fn = 9.580712922458746
# loss_fn = 9.55812816496315
# loss_fn = 9.535620074551208
# loss_fn = 9.51318839096589
# loss_fn = 9.490832854833645
# loss_fn = 9.468553207661422
# loss_fn = 9.44634919183364
# loss_fn = 9.424220550609242
# loss_fn = 9.402167028118704
# loss_fn = 9.380188369361095
# loss_fn = 9.358284320201124
# loss_fn = 9.336454627366178
# loss_fn = 9.314699038443436
# loss_fn = 9.293017301876914
# loss_fn = 9.271409166964563
# loss_fn = 9.249874383855403
# loss_fn = 9.228412703546576
# loss_fn = 9.20702387788052
# loss_fn = 9.185707659542071
# loss_fn = 9.164463802055609
# loss_fn = 9.143292059782215
# loss_fn = 9.122192187916822
# loss_fn = 9.101163942485378
# loss_fn = 9.080207080342063
# loss_fn = 9.059321359166415
# loss_fn = 9.038506537460579
# loss_fn = 9.017762374546509
# loss_fn = 8.997088630563143
# loss_fn = 8.976485066463697
# loss_fn = 8.955951444012832
# loss_fn = 8.935487525783957
# loss_fn = 8.915093075156442
# loss_fn = 8.894767856312908
# loss_fn = 8.874511634236478
# loss_fn = 8.854324174708095
# loss_fn = 8.834205244303762
# loss_fn = 8.814154610391908
# loss_fn = 8.794172041130615
# loss_fn = 8.774257305465035
# loss_fn = 8.754410173124624
# loss_fn = 8.73463041462055
# loss_fn = 8.714917801243011
# loss_fn = 8.695272105058585
# loss_fn = 8.675693098907594
# loss_fn = 8.656180556401502
# loss_fn = 8.636734251920268
# loss_fn = 8.61735396060975
# loss_fn = 8.59803945837912
# loss_fn = 8.578790521898236
# loss_fn = 8.559606928595088
# loss_fn = 8.540488456653225
# loss_fn = 8.521434885009175
# loss_fn = 8.502445993349907
# loss_fn = 8.483521562110253
# loss_fn = 8.464661372470406
# loss_fn = 8.44586520635337
# loss_fn = 8.427132846422435
# loss_fn = 8.40846407607868
# loss_fn = 8.389858679458456
# loss_fn = 8.37131644143089
# loss_fn = 8.352837147595396
# loss_fn = 8.334420584279217
# loss_fn = 8.316066538534919
# loss_fn = 8.297774798137953
# loss_fn = 8.279545151584214
# loss_fn = 8.26137738808754
# loss_fn = 8.243271297577355
# loss_fn = 8.225226670696157
# loss_fn = 8.207243298797163
# loss_fn = 8.189320973941856
# loss_fn = 8.171459488897614
# loss_fn = 8.153658637135266
# loss_fn = 8.135918212826754
# loss_fn = 8.118238010842736
# loss_fn = 8.100617826750193
# loss_fn = 8.083057456810083
# loss_fn = 8.065556697975
# loss_fn = 8.0481153478868
# loss_fn = 8.030733204874274
# loss_fn = 8.013410067950815
# loss_fn = 7.996145736812079
# loss_fn = 7.978940011833709
# loss_fn = 7.9617926940689765
# loss_fn = 7.9447035852465175
# loss_fn = 7.927672487768035
# loss_fn = 7.91069920470598
# loss_fn = 7.893783539801327
# loss_fn = 7.876925297461267
# loss_fn = 7.860124282756967
# tensor(7.8434, dtype=torch.float64)
